# %% [markdown]
# <h1 style="text-align:center; color:#005bbd; font-size:50px; font-family:Sans-serif; font-style: oblique; text-shadow: 0 0 3px white, 0 0 1px Black;">Functions Description</h1>

# %% [markdown]
# <table style="width:90%; border-collapse:collapse; margin:20px; font-size:18px;">
#     <tr>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Function</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">About</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Descriptions</th>
#     </tr>
#     <tr>
#         <td style="border:1px solid black;  padding:10px; text-align:left; text-align:center;">ROW_NUMBER()</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:left;">
#             <ul>Only Use with Over()</ul>
#             <ul>Frames Not supported</ul>
#             <ul>Without Order Also Allowed</ul>
#             <ul>Partition Allowed</ul>
#              <ul>Columns Argument Not Allowed</ul>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:left;">Return Row Unique Number<br>Just Assign a Number<br></td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">RANK()</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:left;">
#         <ul>Only Use with Over()</ul>
#         <ul>Frames Not supported</ul>
#         <ul>Without Order Not Allowed</ul>
#         <ul>Partition Allowed</ul>
#         <ul>Columns Argument Not Allowed</ul>
#         </td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:left;">Return a Unique ROW but Duplicates Consider Single rank<br>Duplicates value assign same rank</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">DENSE_RANK()</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:left;">
#         <ul>Only Use with Over()</ul>
#         <ul>Frames Not supported</ul>
#         <ul>Without Order Not Allowed</ul>
#         <ul>Partition Allowed</ul>
#         <ul>Columns Argument Not Allowed</ul>
#         </td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:left;">Return a Unique ROW but Duplicates Consider as a Different Row</td>
#     <tr>
#         <td style="border:1px solid black;  padding:10px; text-align:left; text-align:center;">AVG()</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:left;">
#             <ul>Also Use with Over()</ul>
#             <ul>Frames supported</ul>
#             <ul>Without Order Also Allowed</ul>
#             <ul>Partition Allowed</ul>
#              <ul>Use With Columns Argument</ul>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:left;">Return Row Unique Number<br>Just Assign a Number<br></td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">MIN()</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:left;">
#         <ul>Also Use with Over()</ul>
#         <ul>Frames supported</ul>
#         <ul>Order Also Allowed</ul>
#         <ul>Partition Allowed</ul>
#         <ul>Use With Columns Argument</ul>
#         </td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:left;">Return a Minimum Value</td>
#     </tr>
#      <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">MAX()</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:left;">
#         <ul>Also Use with Over()</ul>
#         <ul>Frames supported</ul>
#         <ul>Order Also Allowed</ul>
#         <ul>Partition Allowed</ul>
#         <ul>Use With Columns Argument</ul>
#         </td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:left;">Return a Maximum Value</td>
#     </tr>
#      <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">LAG()</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:left;">
#         <ul>Only Use with Over()</ul>
#         <ul>Frames supported</ul>
#         <ul>Only Use With Order</ul>
#         <ul>Partition Allowed</ul>
#         <ul>Use With Columns Argument</ul>
#         </td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:left;">Move value one Step Down</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">LEAD()</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:left;">
#         <ul>Only Use with Over()</ul>
#         <ul>Frames supported</ul>
#         <ul>Only Use With Order</ul>
#         <ul>Partition Allowed</ul>
#         <ul>Use With Columns Argument</ul>
#         </td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:left;">Move value one Step Down to Up</td>
#     </tr>
# </table>
