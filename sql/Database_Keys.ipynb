# %% [markdown]
# <h1 style="text-align:center; color:#005bbd; font-size:50px; font-family:Sans-serif; font-style: oblique; text-shadow: 0 0 3px white, 0 0 1px Black;">DataBases Keys</h1>
# <br>
# <h1 style="text-align:justify; color:black; font-size:25px; font-family:Sans-serif; font-style: oblique; text-shadow: 0 0 3px white, 0 0 1px Black;">A key in a database is an attribute or a set of attributes that uniquely identifies a
# tuple (row) in a table.<br><br>Keys play a crucial role in ensuring the integrity and
# reliability of a database by enforcing unique constraints on the data and
# establishing relationships between tables.<br><br> e.g  Roll No and Email are the example of data integrity</h1>

# %% [markdown]
# <table style="width:100%; border-collapse:collapse; margin:20px; font-size:20px;">
#     <tr>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Roll No</th>
#         <th style="border:1px solid black; padding:10px; text-align:left;text-align:center;">Name</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Branch</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Email</th>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">101</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">John Doe</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Computer Science</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">john.doe@example.com</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">102</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Jane Smith</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Electrical Engineering</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">jane.smith@example.com</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">103</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Alex Johnson</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Mechanical Engineering</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">alex.johnson@example.com</td>
#     </tr>
# </table>

# %% [markdown]
# <div style="text-align:left; color:#005bbd; font-size:30px; font-family:Sans-serif; font-style: oblique; text-shadow: 0 0 3px white, 0 0 1px Black;">Super Key
# <br><br>
# <p style="color:black; font-size:25px">Super key is a combination of columns that uniquely identifies any row
# within a relational database management system (RDBMS) table</p>
# <table style="width:100%; border-collapse:collapse; margin:20px; font-size:20px;">
#     <tr>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Roll No</th>
#         <th style="border:1px solid black; padding:10px; text-align:left;text-align:center;">Name</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Branch</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Email</th>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">101</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">John Doe</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Computer Science</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">john.doe@example.com</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">102</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Jane Smith</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Electrical Engineering</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">jane.smith@example.com</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">103</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Alex Johnson</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Mechanical Engineering</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">alex.johnson@example.com</td>
#     </tr>
# </table>
#
# <h3 style="color:black; font-size:25px">For Example<br>
# <ul>Roll No + Name is the unqiue Combination</ul>
# <ul>Roll No + Branch is the unqiue Combination</ul>
# <ul>Roll No + Email is the unqiue Combination</ul>
# <ul>Can Name is the unqiue Combination ? -> No</ul>
# <ul>Can Name + Branch is the unqiue Combination ? -> No</ul>
# <ul>Can Name + Branch + Email is the unqiue Combination ? -> Yes</ul>
# <ul>Can Roll No + Branch + Email is the unqiue Combination ? -> Yes</ul>
# <br><br>
# So all unique Combination are called Super Key
#
#
# </h3>
# </div>

# %% [markdown]
# <br><br>
#
# <div style="text-align:left; color:#005bbd; font-size:30px; font-family:Sans-serif; font-style: oblique; text-shadow: 0 0 3px white, 0 0 1px Black;">Candidate key
# <br><br>
# <p style="color:black; font-size:25px">A candidate key is a minimal Super key, meaning it has no redundant
# attributes. <br>In other words, it's the smallest set of attributes that can be used to
# uniquely identify a tuple (row) in the table</p>
# <!-- Student Information Table with Random Data -->
# <table style="width:100%; border-collapse:collapse; margin:20px; font-size:20px;">
#     <tr>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Roll No</th>
#         <th style="border:1px solid black; padding:10px; text-align:left;text-align:center;">Name</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Branch</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Email</th>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">101</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">John Doe</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Computer Science</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">john.doe@example.com</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">102</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Jane Smith</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Electrical Engineering</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">jane.smith@example.com</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">103</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Alex Johnson</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Mechanical Engineering</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">alex.johnson@example.com</td>
#     </tr>
# </table>
#
#
# <h3 style="color:black; font-size:25px">For Example<br>
# <ul>Roll No is a Candidate key</ul>
# <ul>Email is a Candidate key</ul>
# <ul>is Roll No + Email is Candidate key ? <br><br><ol style='font-size:22px;'>No, Roll No + Email is not a candidate key because <br>if I can extract data using either Roll No or Email individually, <br>then I should use only one key to avoid redundancy.</ol>  </ul>
#
# So The rows that are sufficient to uniquely identify your data are called candidate keys.
#
#
# </h3>
# </div>

# %% [markdown]
# <br><br>
#
# <div style="text-align:left; color:#005bbd; font-size:30px; font-family:Sans-serif; font-style: oblique; text-shadow: 0 0 3px white, 0 0 1px Black;">Primary key
# <br><br>
# <p style="color:black; font-size:25px">A primary key is a unique identifier for each tuple in a table.<br>There can only be
# one primary key in a table, and it cannot contain null values.</p>
# <table style="width:100%; border-collapse:collapse; margin:20px; font-size:20px;">
#     <tr>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Roll No</th>
#         <th style="border:1px solid black; padding:10px; text-align:left;text-align:center;">Name</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Branch</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Email</th>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">101</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">John Doe</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Computer Science</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">john.doe@example.com</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">102</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Jane Smith</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Electrical Engineering</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">jane.smith@example.com</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">103</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Alex Johnson</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Mechanical Engineering</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">alex.johnson@example.com</td>
#     </tr>
# </table>
#
# <h3 style="color:black; font-size:25px">For Example<br>
# <ul>Roll No is a Primary key </ul>
# <ul>Email is a Primary key</ul><br>
# <ul> Requirment of Primary key<br><br>
# <ol style="font-size:25px;">Primary Key cant be NULL</ol>
# <ol style="font-size:25px;">Primary Key is must be Unique</ol>
# <ol style="font-size:25px;">Primary Key is small in Size like a number</ol>
# <ol style="font-size:25px;">Primary Key must be constant</ol>
#
#
# </ul>
#
# So Unqiue Columns are use as a Primary Key
#
#
# </h3>
# </div>

# %% [markdown]
# <br><br>
#
# <div style="text-align:left; color:#005bbd; font-size:30px; font-family:Sans-serif; font-style: oblique; text-shadow: 0 0 3px white, 0 0 1px Black;">Alternate Key
# <br><br>
# <p style="color:black; font-size:25px">An alternate key is a candidate key that is not used as the primary key.</p>
# <table style="width:100%; border-collapse:collapse; margin:20px; font-size:20px;">
#     <tr>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Roll No</th>
#         <th style="border:1px solid black; padding:10px; text-align:left;text-align:center;">Name</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Branch</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Email</th>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">101</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">John Doe</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Computer Science</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">john.doe@example.com</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">102</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Jane Smith</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Electrical Engineering</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">jane.smith@example.com</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">103</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Alex Johnson</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Mechanical Engineering</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">alex.johnson@example.com</td>
#     </tr>
# </table>
#
# <h3 style="color:black; font-size:25px">For Example<br>
# <ul>Roll No is a Primary key </ul>
# <ul>Email is a Primary key</ul><br>
# <ol style="font-size:20px;   letter-spacing: 1px;   line-height: 200%;">So, Roll No is a primary key, and Email is also a primary key.<br>However, when comparing the two, Roll No is considered the best primary key <br>because it is unique and serves the purpose well.<br>Email, on the other hand, can be considered as an alternate key since<br>we have another primary key (Roll No) available.</ol>
#
# </ul>
#
#
# </h3>
# </div>

# %% [markdown]
# <br><br>
#
# <div style="text-align:left; color:#005bbd; font-size:30px; font-family:Sans-serif; font-style: oblique; text-shadow: 0 0 3px white, 0 0 1px Black;">Composite Key
# <br><br>
# <p style="color:black; font-size:25px">A composite key is a primary key that is made up of two or more attributes<br>
# Composite keys are used when a single attribute is not sufficient to uniquely
# identify a tuple in a table</p>
# <!-- Enrollment Table -->
# <table style="width:80%; border-collapse:collapse; margin:20px; font-size:20px;">
#     <tr>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">EmployeeID</th>
#         <th style="border:1px solid black; padding:10px; text-align:left;text-align:center;">ProjectID</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">AssignmentDate</th>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">1</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">101</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">2023-05-15</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">2</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">102</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">2023-05-18</td>
#     </tr>
# </table>
#
#
# <h3 style="color:black; font-size:25px">For Example<br>
# <ul style="letter-spacing: 1px;   line-height: 200%; letter-spacing: 1px;">Suppose we have a table called "ProjectAssignments" with the following attributes:
# <ol>EmployeeID</ol>
# <ol>ProjectID</ol>
# <ol>AssignmentDate</ol>
# In this scenario, using a single attribute like "EmployeeID" or "ProjectID" alone may not be sufficient to uniquely identify a tuple because an employee can be assigned to multiple projects on different dates, and a project can involve multiple employees on different dates. </ul>
# <ol style="font-size:20px;   letter-spacing: 1px;   line-height: 200%;">So, to uniquely identify each assignment, you can use a composite key made up of both "EmployeeID" and "ProjectID."<br> This combination ensures that each assignment is uniquely identified, as an employee can be assigned to the same project on different dates, and different employees can be assigned to the same project on different dates.</ol>
#
# </ul>
#
#
# </h3>
# </div>

# %% [markdown]
# <br><br>
#
# <div style="text-align:left; color:#005bbd; font-size:30px; font-family:Sans-serif; font-style: oblique; text-shadow: 0 0 3px white, 0 0 1px Black;">Surrogate Key
# <br><br>
# <p style="color:black; font-size:25px">A surrogate key is a unique identification number created solely for the purpose of distinguishing records in a database table.<br> Unlike keys based on actual data (like names or dates), surrogate keys have no inherent meaning and ensure each record is uniquely identified. <br>They simplify database management and enhance data reliability.</p>
#
# <table style="width:100%; border-collapse:collapse; margin:20px; font-size:20px;">
#     <tr>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Name</th>
#         <th style="border:1px solid black; padding:10px; text-align:left;text-align:center;">Branch</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">CGPA</th>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">John Doe</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Computer Science</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">3.8</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Jane Smith</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Electrical Engineering</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">3.5</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Alex Johnson</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Mechanical Engineering</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">3.2</td>
#     </tr>
# </table>
#
#
# <h3 style="color:black; font-size:25px">For Example<br>
# <ul style="letter-spacing: 1px;   line-height: 200%; letter-spacing: 1px;">In a student information table with columns like name, branch, and CGPA, we face a challenge in finding a suitable primary key. Let's break it down:<br><br>
# Name as a Primary Key: <ol>No, because one name can correspond to multiple students.</ol><br>
# Branch as a Primary Key: <ol>No, because one branch can have multiple students.</ol><br>
# CGPA as a Primary Key: <ol>No, because multiple students can have the same CGPA.</ol><br>
# Name + Branch as a Primary Key: <ol>No, because multiple students can share the same name and branch.</ol><br>
# Name + Branch + CGPA as a Primary Key: <ol>No, because students with the same name and branch can have the same CGPA.</ol><br><br>
# </ul>
# <ol style="font-size:20px;   letter-spacing: 1px;   line-height: 200%;">To address this, a new column, let's call it "student_id," needs to be added. <br>This new column, known as a Surrogate Key, can serve as a unique identifier for each student. <br><table style="width:100%; border-collapse:collapse; margin:20px; font-size:20px;">
#     <tr>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Student ID</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Name</th>
#         <th style="border:1px solid black; padding:10px; text-align:left;text-align:center;">Branch</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">CGPA</th>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">1</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">John Doe</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Computer Science</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">3.8</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">2</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Jane Smith</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Electrical Engineering</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">3.5</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">3</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Alex Johnson</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Mechanical Engineering</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">3.2</td>
#     </tr>
#     <!-- Additional rows for different students -->
# </table><br>Now, the combination of "student_id" and the other columns can be used as the primary key, ensuring each student is uniquely identified.</ol>
#
# </ul>
#
#
# </h3>
# </div>

# %% [markdown]
# <br><br>
#
# <div style="text-align:left; color:#005bbd; font-size:30px; font-family:Sans-serif; font-style: oblique; text-shadow: 0 0 3px white, 0 0 1px Black;">Foreign Key
# <br><br>
# <p style="color:black; font-size:25px">A foreign key is a primary key from one table that is used to establish a
# relationship with another table.</p>
#
#
# <table style="width:80%; border-collapse:collapse; margin:20px; font-size:20px;">
#     <tr>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">StudentID</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Name</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Branch</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Email</th>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">1</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">John Doe</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Computer Science</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">john.doe@example.com</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">2</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Jane Smith</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Electrical Engineering</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">jane.smith@example.com</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">3</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Alex Johnson</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Mechanical Engineering</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">alex.johnson@example.com</td>
#     </tr>
# </table>
#
# <ul style="letter-spacing: 1px;   line-height: 200%; letter-spacing: 1px; color:black; font-size:20px;">StudentID: <ol>This is the primary key, a unique identifier for each student.</ol><br>
# </ul>
#
# <table style="width:80%; border-collapse:collapse; margin:20px; font-size:20px;">
#     <tr>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">CourseID</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">CourseName</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Instructor</th>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">101</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Introduction to CS</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Prof. Anderson</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">102</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Circuit Analysis</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Prof. Martinez</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">103</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Thermodynamics</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Prof. Robinson</td>
#     </tr>
# </table>
#
#
# <ul style="letter-spacing: 1px;   line-height: 200%; letter-spacing: 1px; color:black; font-size:20px;">CourseID: <ol>This is the primary key, a unique identifier for each course.</ol><br>
# </ul>
#
# <h4 style="color:black;">Enrollments Table (with Foreign Key)</h4>
# <!-- Enrollments Table with Foreign Key -->
# <table style="width:80%; border-collapse:collapse; margin:20px; font-size:20px;">
#     <tr>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">EnrollmentID</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">StudentID</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">CourseID</th>
#         <th style="border:1px solid black; padding:10px; text-align:left; text-align:center;">Grade</th>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">1</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">1</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">101</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">A</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">2</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">2</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">102</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">B</td>
#     </tr>
#     <tr>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">3</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">3</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">103</td>
#         <td style="border:1px solid black; padding:10px; text-align:left; text-align:center;">A-</td>
#     </tr>
# </table>
# <ul style="letter-spacing: 1px;   line-height: 200%; letter-spacing: 1px; color:black; font-size:20px;">EnrollmentID:<ol>This is the primary key, a unique identifier for each enrollment.</ol><br>
# </ul><br><br>
#
# <ul style="letter-spacing: 1px;   line-height: 200%; letter-spacing: 1px; color:black; font-size:20px;">Certainly! Let's break down the concept of foreign keys and their relationship between the "Students" and "Courses" tables step by step:<br><br>
#
#
#
# <ul style="letter-spacing: 1px;   line-height: 200%; letter-spacing: 1px; color:black; font-size:20px;">StudentID (Foreign Key):<ol>Connects to the "StudentID" in the "Students" table.<br>It references the primary key of the "Students" table, establishing a link between students and enrollments.</ol></ul><br>
#
#
# <ul style="letter-spacing: 1px;   line-height: 200%; letter-spacing: 1px; color:black; font-size:20px;">CourseID (Foreign Key):
# <ol> Connects to the "CourseID" in the "Courses" table. It references the primary key of the "Courses" table, establishing a link between courses and enrollments.</ol></ul><br>
#
# <ul style="letter-spacing: 1px;   line-height: 200%; letter-spacing: 1px; color:black; font-size:20px;">EnrollmentID:<ol>This is the primary key, a unique identifier for each enrollment.</ol></ul><br>
#
# <ul style="letter-spacing: 1px;   line-height: 200%; letter-spacing: 1px; color:black; font-size:20px;">Grade:<ol>Represents the grade the student received in the course.</ol></ul><br>
#
# <h3 style="letter-spacing: 1px;   line-height: 200%; letter-spacing: 1px; color:black; font-size:30px;">Relationship:</h3><br>
#
# <ol style="font-size:20px;   letter-spacing: 1px;   line-height: 200%;">The "StudentID" in the "Enrollments" table links to the "StudentID" in the "Students" table, creating a connection between students and their enrollments.<br>
# Similarly, the "CourseID" in the "Enrollments" table links to the "CourseID" in the "Courses" table, creating a connection between courses and enrollments.<br><br>
# This way, the "Enrollments" table acts as a bridge, connecting students to courses through foreign keys, allowing you to see which students are enrolled in which courses and their corresponding grades.<br>
#
# </div>
