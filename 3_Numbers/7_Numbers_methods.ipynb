# %% [markdown]
# float
#
# as_integer_ratio', 'conjugate', 'fromhex', 'hex', 'imag', 'is_integer', 'real

# %%
x.denominator
# Out:
# 3

# %%
x.numerator
# Out:
# 2

# %%
x.real
# Out:
# 10

# %%
x.imag
# Out:
# 0

# %%
x.to_bytes(10,"big")
# Out:
# b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\n'
