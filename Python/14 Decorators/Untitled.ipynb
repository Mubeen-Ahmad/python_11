# %% [markdown]
# # Decorators
#
# <h3 style="color:#4e2abd;">
# A decorator in python is a function that receives another function as input and adds some functionality(decoration) to and it and returns it.<br><br>This can happen only because python functions are 1st class citizens.
# <br><br>There are 2 types of decorators available in python<br><br>
# Built in decorators : like @staticmethod, @classmethod, @abstractmethod and @property etc<br><br>
#
# User defined decorators : that we programmers can create according to our needs
#
# </h3>

# %% [markdown]
# ### First class citizen
# ## means we can perform Multiple opertions , and action with functions like modify , remove etc

# %%
def modify(func,num):
    
    return func(num)

# %%
def square(num):
    
    return num ** 2

# %%
# pass function to other funtion

modify(square,2)
# Out:
# 4

# %% [markdown]
# # Simple UnderStand

# %%
def func():
    
    print("hello")

# %%
print(func)
# Out:
# <function func at 0x7fdaf581dab0>

# %% [markdown]
# ## here i can't call function thats why return the function object

# %%
x = func

print(x)

# also return object because cant call the function
# Out:
# <function func at 0x7fdaf581dab0>

# %% [markdown]
# # Create Decorator

# %%
def decorator(func):
    
    
    def wrapper():
        print("******************** Start ********************")
        
        # call func (argument of decorator function)
        func()
        
        print("******************** End ********************")
        
    # call wrapper function
    wrapper()

# %%
def hello():
    print("Hello")

# %%
# hello pass in decorator hello = func 

# and func() call inside the wrapper function so first need to call wrapper

# wrapper() ---> func() ----> print start ,hello() ,print end  


decorator(hello)
# Out:
# ******************** Start ********************
# Hello
# ******************** End ********************

# %% [markdown]
# # return wrapper

# %%
def decorator(func):
    
    
    def wrapper():
        print("******************** Start ********************")
        
        # call func (argument of decorator function)
        
        func()
                
        print("******************** End ********************")
    
    # call wrapper function
    return wrapper()

# %%
def hello():
    print("Hello")

# %%
decorator(hello)
# Out:
# ******************** Start ********************
# Hello
# ******************** End ********************
